# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. train_data

# %%
train_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/train.csv')

# %%
train_data.head(5)
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
train_data.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
# # 2. store_data

# %%
store_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/clean_store_data.csv')

# %%
store_data.head(5)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0             22.0           2012.0
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0             22.0           2012.0
# 4                    2015.0       0             22.0           2012.0
#
#      PromoInterval
# 0          Unknown
# 1  Jan,Apr,Jul,Oct
# ...

# %%
store_data.isnull().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %% [markdown]
# # 3. test_data

# %%
test_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/clean_test_data.csv')

# %%
test_data.head(5)
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
test_data.isnull().sum()
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Date             0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
# # 4. train_store_data

# %%
train_store_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/train_store_data.csv')

# %%
train_store_data.head(5)
# Out:
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5   5263        555     1      1            0
# 1      2          5   6064        625     1      1            0
# 2      3          5   8314        821     1      1            0
# 3      5          5   4822        559     1      1            0
# 4      6          5   5651        589     1      1            0
#
#    SchoolHoliday  Year  Month  ...  StoreType  Assortment CompetitionDistance  \
# 0              1  2015      7  ...          c           a              1270.0
# 1              1  2015      7  ...          a           a               570.0
# 2              1  2015      7  ...          a           a             14130.0
# 3              1  2015      7  ...          a           a             29910.0
# 4              1  2015      7  ...          a           a               310.0
#
#   CompetitionOpenSinceMonth CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  \
# ...

# %%
train_store_data.isnull().sum()
# Out:
# Store                        0
# DayOfWeek                    0
# Sales                        0
# Customers                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# Year                         0
# Month                        0
# Day                          0
# WeekOfYear                   0
# Dates                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# HolidayPeriod                0
# dtype: int64

# %%
train_store_data.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Day', 'WeekOfYear',
#        'Dates', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval', 'HolidayPeriod'],
#       dtype='object')
