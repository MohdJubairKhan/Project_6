# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. train_data

# %%
train_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/train.csv')

# %%
train_data.head(5)
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
train_data.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
train_data.shape
# Out:
# (1017209, 9)

# %%
train_data.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %% [markdown]
# # 2. Test_data

# %%
test_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/test.csv')

# %%
test_data.head(5)
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
test_data.isnull().sum()
# Out:
# Id                0
# Store             0
# DayOfWeek         0
# Date              0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64

# %%
test_data.shape
# Out:
# (41088, 8)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %%
test_data = test_data.fillna({'Open': 0})

# %%
test_data.isnull().sum()
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Date             0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
test_data.columns
# Out:
# Index(['Id', 'Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday',
#        'SchoolHoliday'],
#       dtype='object')

# %% [markdown]
# # 3. Store_data

# %%
store_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/store.csv')

# %%
store_data.head(5)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
store_data.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store_data.shape
# Out:
# (1115, 10)

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
#  Filling numerical missing values with median
numerical_cols = store_data.select_dtypes(include=['float64', 'int64']).columns
store_data[numerical_cols] = store_data[numerical_cols].apply(lambda x: x.fillna(x.median()), axis=0)

# %%
# Filling categorical missing values with 'Unknown'
categorical_cols = store_data.select_dtypes(include=['object']).columns
store_data[categorical_cols] = store_data[categorical_cols].apply(lambda x: x.fillna('Unknown'))

# %%
store_data.isnull().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %% [markdown]
# # 4. Sample_Submission_data

# %%
sample_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/sample_submission.csv')

# %%
sample_data.head(5)
# Out:
#    Id  Sales
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0

# %%
sample_data.isnull().sum()
# Out:
# Id       0
# Sales    0
# dtype: int64

# %%
sample_data.shape
# Out:
# (41088, 2)

# %% [markdown]
# # Merging 'train.csv' and 'store.csv'

# %% [markdown]
# # Both dataset have common column 'store'
# We use that column to merge store into train dataset

# %%
train_data['Date'] = pd.to_datetime(train_data['Date'])
train_data.set_index('Date', inplace=True)
train_data['Year'] = train_data.index.year
train_data['Month'] = train_data.index.month
train_data['Day'] = train_data.index.day
train_data['WeekOfYear'] = train_data.index.isocalendar().week
train_data['Dates']=train_data.apply(lambda x:'%s-%s-%s' % (x['Year'],x['Month'],x['Day']),axis=1)
train_data['Dates']=pd.to_datetime(train_data['Dates'])

# %%
train_data.head(5)
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
#
#             SchoolHoliday  Year  Month  Day  WeekOfYear      Dates
# Date
# 2015-07-31              1  2015      7   31          31 2015-07-31
# 2015-07-31              1  2015      7   31          31 2015-07-31
# 2015-07-31              1  2015      7   31          31 2015-07-31
# 2015-07-31              1  2015      7   31          31 2015-07-31
# 2015-07-31              1  2015      7   31          31 2015-07-31

# %%
train_data.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Day', 'WeekOfYear',
#        'Dates'],
#       dtype='object')

# %%
train_data.shape
# Out:
# (1017209, 13)

# %%
train_store_data = pd.merge(train_data, store_data, how = 'inner', on = 'Store')

# %%
train_store_data.head(5)
# Out:
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5   5263        555     1      1            0
# 1      2          5   6064        625     1      1            0
# 2      3          5   8314        821     1      1            0
# 3      4          5  13995       1498     1      1            0
# 4      5          5   4822        559     1      1            0
#
#    SchoolHoliday  Year  Month  ...      Dates  StoreType Assortment  \
# 0              1  2015      7  ... 2015-07-31          c          a
# 1              1  2015      7  ... 2015-07-31          a          a
# 2              1  2015      7  ... 2015-07-31          a          a
# 3              1  2015      7  ... 2015-07-31          c          c
# 4              1  2015      7  ... 2015-07-31          a          a
#
#   CompetitionDistance CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# 0              1270.0                       9.0                    2008.0
# 1               570.0                      11.0                    2007.0
# 2             14130.0                      12.0                    2006.0
# 3               620.0                       9.0                    2009.0
# 4             29910.0                       4.0                    2015.0
#
#    Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0       0             22.0           2012.0          Unknown
# 1       1             13.0           2010.0  Jan,Apr,Jul,Oct
# 2       1             14.0           2011.0  Jan,Apr,Jul,Oct
# 3       0             22.0           2012.0          Unknown
# 4       0             22.0           2012.0          Unknown
#
# [5 rows x 22 columns]

# %%
train_store_data.shape
# Out:
# (1017209, 22)

# %%
train_store_data.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
#
#               Promo  SchoolHoliday          Year         Month           Day  \
# count  1.017209e+06   1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   3.815145e-01   1.786467e-01  2.013832e+03  5.846762e+00  1.570279e+01
# min    0.000000e+00   0.000000e+00  2.013000e+03  1.000000e+00  1.000000e+00
# 25%    0.000000e+00   0.000000e+00  2.013000e+03  3.000000e+00  8.000000e+00
# 50%    0.000000e+00   0.000000e+00  2.014000e+03  6.000000e+00  1.600000e+01
# 75%    1.000000e+00   0.000000e+00  2.014000e+03  8.000000e+00  2.300000e+01
# max    1.000000e+00   1.000000e+00  2.015000e+03  1.200000e+01  3.100000e+01
# std    4.857586e-01   3.830564e-01  7.773960e-01  3.326097e+00  8.787638e+00
#
#        WeekOfYear                          Dates  CompetitionDistance  \
# count   1017209.0                        1017209         1.017209e+06
# mean    23.615515  2014-04-11 01:30:42.846061824         5.422021e+03
# min           1.0            2013-01-01 00:00:00         2.000000e+01
# 25%          11.0            2013-08-17 00:00:00         7.100000e+02
# 50%          22.0            2014-04-02 00:00:00         2.325000e+03
# 75%          35.0            2014-12-12 00:00:00         6.880000e+03
# max          52.0            2015-07-31 00:00:00         7.586000e+04
# std     14.433381                            NaN         7.706918e+03
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear        Promo2  \
# count               1.017209e+06              1.017209e+06  1.017209e+06
# mean                7.469899e+00              2.009107e+03  5.005638e-01
# min                 1.000000e+00              1.900000e+03  0.000000e+00
# 25%                 6.000000e+00              2.008000e+03  0.000000e+00
# 50%                 8.000000e+00              2.010000e+03  1.000000e+00
# 75%                 9.000000e+00              2.011000e+03  1.000000e+00
# max                 1.200000e+01              2.015000e+03  1.000000e+00
# std                 2.677243e+00              4.986802e+00  4.999999e-01
#
#        Promo2SinceWeek  Promo2SinceYear
# count     1.017209e+06     1.017209e+06
# mean      2.263526e+01     2.011876e+03
# min       1.000000e+00     2.009000e+03
# 25%       2.200000e+01     2.012000e+03
# 50%       2.200000e+01     2.012000e+03
# 75%       2.200000e+01     2.012000e+03
# max       5.000000e+01     2.015000e+03
# std       9.993137e+00     1.182965e+00

# %% [markdown]
# # We can see that there are some outliers in sales and customers distribuiton

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
train_store_data.boxplot(column='Sales')
plt.title('Outlier in Sales Column')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
train_store_data.boxplot(column='Customers')
plt.title('Outlier in Customers Column')
plt.ylabel('Customers')
plt.show()

# %% [markdown]
# # Remove Outliers

# %%
def iqr_technique(DFcolumn):
  Q1 = np.percentile(DFcolumn, 25)
  Q3 = np.percentile(DFcolumn, 75)
  IQR = Q3 - Q1
  lower_range = Q1 - (1.5 * IQR)
  upper_range = Q3 + (1.5 * IQR)                        

  return lower_range,upper_range

# %% [markdown]
# # For Sales Column

# %%
lower_bound,upper_bound = iqr_technique(train_store_data['Sales'])

train_store_data = train_store_data[(train_store_data.Sales>lower_bound) & (train_store_data.Sales<upper_bound)]

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
train_store_data.boxplot(column='Sales')
plt.title('Outlier in Sales Column')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # For Customers Column

# %%
lower_bound,upper_bound = iqr_technique(train_store_data['Customers'])

train_store_data = train_store_data[(train_store_data.Customers>lower_bound) & (train_store_data.Customers<upper_bound)]

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
train_store_data.boxplot(column='Customers')
plt.title('Outlier in Customers Column')
plt.ylabel('Customers')
plt.show()

# %% [markdown]
# # Reading the description report

# %% [markdown]
# # Sales
# The minimum sale is 0
#
# The maximum sale is 41551.00
#
# 25% of sale is below 3727.000
#
# 50% of sale is below 5744.000
#
# 75% of sale is below 7856.000

# %% [markdown]
# # Customers
# The minimum customer is 0
#
# The maximum customer is 7388
#
# 25% of customer is below 405
#
# 50% of customer is below 609
#
# 75% of customer is below 837

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # 1.1- Distribution of Promotions in Training and Test Sets

# %%
sns.countplot(x='Promo', data=train_data)
plt.title('Promo Distribution in Training Set')
plt.show()

# %%
sns.countplot(x='Promo', data=test_data)
plt.title('Promo Distribution in Test Set')
plt.show()

# %% [markdown]
# # 1.2- Sales Behavior Before, During, and After Holidays

# %%
# Convert Dates to datetime
train_store_data['Dates'] = pd.to_datetime(train_store_data['Dates'])

# %% [markdown]
# # Create a feature to indicate whether the day is during holiday

# %%
train_store_data['HolidayPeriod'] = 'Regular'
train_store_data.loc[train_store_data['StateHoliday'] != '0', 'HolidayPeriod'] = 'During Holiday'

# %% [markdown]
# # Create a feature to indicate whether the day is after holiday

# %%
train_store_data.loc[(train_store_data['StateHoliday'] == '0') & 
                     (train_store_data['Dates'].dt.dayofweek == 0) & 
                     (train_store_data['Dates'].shift(1).dt.dayofweek == 6), 'HolidayPeriod'] = 'After Holiday'

# %% [markdown]
# # Create a feature to indicate whether the day is before holiday

# %%
train_store_data.loc[(train_store_data['StateHoliday'] == '0') & 
                     (train_store_data['Dates'].dt.dayofweek == 6) & 
                     (train_store_data['Dates'].shift(-1).dt.dayofweek == 0), 'HolidayPeriod'] = 'Before Holiday'

# %% [markdown]
# # Plot sales behavior during different holiday periods

# %%
sns.boxplot(x='HolidayPeriod', y='Sales', data=train_store_data)
plt.title('Sales Behavior Before, During, and After Holidays')
plt.show()

# %% [markdown]
# # 1.3- Seasonal Purchase Behaviors (Christmas, Easter, etc.)

# %%
# Extract month and day for easier seasonal analysis
train_store_data['Month'] = train_store_data['Dates'].dt.month
train_store_data['Day'] = train_store_data['Dates'].dt.day

# %%
# Plot sales by month to identify seasonal patterns
monthly_sales = train_store_data.groupby('Month')['Sales'].sum().reset_index()
sns.lineplot(x='Month', y='Sales', data=monthly_sales)
plt.title('Monthly Sales Patterns')
plt.show()

# %% [markdown]
# # 1.4- Correlation Between Sales and Number of Customers

# %%
sns.scatterplot(x='Customers', y='Sales', data=train_store_data)
plt.title('Correlation Between Sales and Number of Customers')
plt.show()

# %%
train_store_data[['Customers','Sales']].corr()
# Out:
#            Customers     Sales
# Customers   1.000000  0.913211
# Sales       0.913211  1.000000

# %% [markdown]
# # 1.5- Effect of Promos on Sales

# %%
sns.boxplot(x='Promo', y='Sales', data=train_store_data)
plt.title('Effect of Promo on Sales')
plt.show()

# %%
train_store_data[['Promo','Sales']].corr()
# Out:
#           Promo     Sales
# Promo  1.000000  0.483838
# Sales  0.483838  1.000000

# %%
# Correlation between promo, Customers and sales
train_store_data[['Promo', 'Customers','Sales']].corr()
# Out:
#               Promo  Customers     Sales
# Promo      1.000000   0.375400  0.483838
# Customers  0.375400   1.000000  0.913211
# Sales      0.483838   0.913211  1.000000

# %% [markdown]
# # 1.6- Deployment of Promos in Stores

# %%
# Analyze the effect of promo on customers
sns.boxplot(x='Promo', y='Customers', data=train_store_data)
plt.title('Effect of Promo on Customer Count')
plt.show()

# %%
train_store_data[['Promo', 'Customers']].corr()
# Out:
#             Promo  Customers
# Promo      1.0000     0.3754
# Customers  0.3754     1.0000

# %%
# Check store-wise promo effect
store_promo_effect = train_store_data.groupby('Store')[['Promo', 'Sales']].mean().reset_index()
sns.scatterplot(x='Promo', y='Sales', data=store_promo_effect)
plt.title('Store-wise Promo Effect on Sales')
plt.show()

# %% [markdown]
# # 1.7- Customer Behavior During Store Open and Closing Times

# %%
# Analyze sales patterns by day of the week
sns.boxplot(x='DayOfWeek', y='Sales', data=train_store_data)
plt.title('Sales Patterns by Day of the Week')
plt.show()

# %% [markdown]
# # 1.8- Weekday Open Stores and Weekend Sales

# %%
# Identify stores that are open on all weekdays
weekday_data = train_store_data[train_store_data['DayOfWeek'].isin([1, 2, 3, 4, 5])]
weekday_open_stores = train_store_data.groupby('Store')['Open'].sum().reset_index()
weekday_open_stores = weekday_open_stores[weekday_open_stores == 5].index.tolist()

# %%
# Compare weekend sales for these stores
weekend_sales = train_store_data[(train_store_data['Store'].isin(weekday_open_stores)) & (train_store_data['DayOfWeek'] >= 6)]
sns.boxplot(x='DayOfWeek', y='Sales', data=weekend_sales)
plt.title('Weekend Sales for Stores Open on All Weekdays')
plt.show()

# %% [markdown]
# # 1.9- Effect of Assortment Type on Sales

# %%
# Analyze the effect of assortment type on sales
sns.boxplot(x='Assortment', y='Sales', data=train_store_data)
plt.title('Effect of Assortment Type on Sales')
plt.show()

# %% [markdown]
# # 1.10- Impact of Competitor Distance on Sales

# %%
# Scatter plot of CompetitionDistance vs Sales
plt.figure(figsize=(12, 6))
sns.scatterplot(x='CompetitionDistance', y='Sales', data=train_store_data)
plt.title('Effect of Competitor Distance on Sales')
plt.xlabel('Competition Distance')
plt.ylabel('Sales')
plt.show()

# %%
# Assume city center stores have a high density of competitors and a short distance
city_center_stores = train_store_data[train_store_data['CompetitionDistance'] < 1000]

# %%
# Scatter plot for city center stores
plt.figure(figsize=(12, 6))
sns.scatterplot(x='CompetitionDistance', y='Sales', data=city_center_stores)
plt.title('Effect of Competitor Distance on Sales in City Centers')
plt.xlabel('Competition Distance')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # 1.11- Effect of New Competitors

# %%
# Identify stores with NA initially in CompetitionDistance and later values
initial_na_competition = train_store_data[train_store_data['CompetitionDistance'].isna()]
later_competition = train_store_data[train_store_data['CompetitionDistance'].notna()]

# %%
# Analyze the sales before and after the competition opens
initial_sales = initial_na_competition.groupby('Store')['Sales'].mean()
later_sales = later_competition.groupby('Store')['Sales'].mean()

# %%
sales_effect = later_sales - initial_sales
print(sales_effect)
# Out:
# Store
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
#         ..
# 1111   NaN
# 1112   NaN
# 1113   NaN
# 1114   NaN
# 1115   NaN
# Name: Sales, Length: 1113, dtype: float64

# %%
train_store_data.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Day', 'WeekOfYear',
#        'Dates', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval', 'HolidayPeriod'],
#       dtype='object')

# %%
train_store_data.shape
# Out:
# (967874, 23)

# %%
train_store_data.to_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/train_store_data.csv',index=False)

# %%
store_data.to_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/clean_store_data.csv',index=False)

# %%
test_data.to_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/Project_6/data/clean_test_data.csv',index=False)
